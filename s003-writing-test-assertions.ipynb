# %% [markdown]
# # Assertions

# %% [markdown]
# A **test assertion** is a statement that evaluates to either `True` or `False`.
#
# We use assertions as checks to determine if the results of our test have passed or failed:
# * **`True`** means passed
# * **`False`** means failed.
#
# The nice thing about assertions is that they will raise an exception if they evaluate to **`False`**, marking the test as failed.
#
# Assertions are native to Python, and you can make one using the **`assert()`** function call.
#
# Consider this example.

# %%
def sum(a, b):
    return a + b

answer = sum(2, 3)
assert(answer==5)

# %% [markdown]
# # Options for python assertions

# %% [markdown]
# * You could use the **`assert()`** function in all of your tests.
# * But in python, there’s a nicer way to make assertions: using additional **`asserts`** that **`TestCase`** provides.
# * Remember that our test case class is inherited from **`unittest.TestCase`**, so, there we have access to a lot of assertions to make your code cleaner.
# * These assertions are just **“syntactic sugar”** over the **`assert()`** function, but they’re nicer and a bit easier to read.

# %% [markdown]
# # Common assertions for PyUnit

# %% [markdown]
# ![image.png](attachment:3c5c9223-7d68-4a82-995f-968ce25b5155.png)

# %% [markdown]
# # Area of a triangle function

# %% [markdown]
# ![image.png](attachment:f0093b08-f32c-44ad-922d-d9ef855e9d03.png)

# %% [markdown]
# # Testing area of triangle function

# %% [markdown]
# ![image.png](attachment:ebe7bb13-2fa2-4b14-9641-656f730dbe5f.png)
